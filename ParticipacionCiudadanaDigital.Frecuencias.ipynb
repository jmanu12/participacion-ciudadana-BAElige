# %%
#Lectura de datos
library(stats)
library("ggplot2")
data <- read.csv('ParticipacionCiudadana.csv', header=TRUE, sep=",")
head(data)
# Out:
#   Apoyos Votos Comuna    Year  Categoria            Viabilidad
# 1 1620   1024  Comuna 9  2017' Plazas y parques     Viable
# 2   18    852  Comuna 13 2017' Plazas y parques     Viable
# 3    8    651  Comuna 13 2017' Movilidad y transito Viable
# 4  891    615  Comuna 12 2017' Plazas y parques     Viable
# 5    6    610  Comuna 14 2017' Movilidad y transito Viable
# 6    7    601  Comuna 2  2017' Movilidad y transito Viable

# %%
columnDataFrame <- function(data, columnName){
    #Si los valores de entrada de la función es no nula
    if (!is.null(data)  & !is.null(columnName) ){
        #le pasamos el nombre de la columna y la matriz de datos
        indx <- grepl(columnName, colnames(data))
        #recuperamos la columna desceada
        result  <- data[indx]
    }
}

# %% [markdown]
# <h1>Todas las comunas : Año 2017−2018−2019</h1>

# %%
# counts
#TODO: INCLUIR EL NUMERO EN CADA BARRA
ggplot(data, aes(x=Categoria)) +
                geom_bar(fill="steelblue")+ 
                theme_bw()+
                labs(x="", y = "Frecuencia", title = "Frecuencia de Categorias para todas las comunas, año : 2017, 2018, 2019")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))

# counts
#TODO: INCLUIR EL NUMERO EN CADA BARRA
ggplot(data, aes(x=Year)) +
                geom_bar(fill="steelblue")+ 
                theme_bw()+
                labs(x="", y = "Frecuencia", title = "Frecuencia de Propuestas por Año")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))

# counts
#TODO: INCLUIR EL NUMERO EN CADA BARRA
ggplot(data, aes(x=Comuna)) +
                geom_bar(fill="steelblue")+ 
                theme_bw()+
                labs(x="", y = "Frecuencia", title = "Frecuencia de Participación por comuna, año: 2017, 2018, 2019")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))

# counts
#TODO: INCLUIR EL NUMERO EN CADA BARRA
ggplot(data, aes(x=Viabilidad)) +
                geom_bar(fill="steelblue")+ 
                theme_bw()+
                labs(x="", y = "Frecuencia", title = "Frecuencia de Viabilidad: 2017, 2018, 2019 ")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# <h1>Votos y Apoyos por año para cada comuna</h1>

# %%
# Grouped
ggplot(data, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Número de votos por año para cada comuna")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(data, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Número de 'Apoyos' por año para cada comuna")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %% [markdown]
# <h1>Votos y Apoyos por año para cada categoría de propuesta</h1>

# %%
# Grouped
ggplot(data, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Número de votos por año para cada Categoría")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(data, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Número de 'Apoyos' por año para cada Categoría")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %% [markdown]
# <h1>Votos y Apoyos para las Comunas:</h1>

# %%
Comuna1 <- filter(data, Comuna=="Comuna 1"  )
# Grouped
ggplot(Comuna1, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Categoría: Comuna 1")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(Comuna1, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Categoría: Comuna 1")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Comuna <- filter(data, Comuna=="Comuna 2"  )
# Grouped
ggplot(Comuna1, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Categoría: Comuna 2")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(Comuna, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Categoría: Comuna 2")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Comuna <- filter(data, Comuna=="Comuna 11"  )
# Grouped
ggplot(Comuna, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Categoría: Comuna 11")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(Comuna, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Categoría: Comuna 11")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Comuna <- filter(data, Comuna=="Comuna 12"  )
# Grouped
ggplot(Comuna, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Categoría: Comuna 12")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(Comuna, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Categoría: Comuna 12")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Comuna <- filter(data, Comuna=="Comuna 4"  )
# Grouped
ggplot(Comuna1, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Categoría: Comuna 4")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(Comuna, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Categoría: Comuna 4")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Comuna <- filter(data, Comuna=="Comuna 8"  )
# Grouped
ggplot(Comuna1, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Categoría: Comuna 8")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(Comuna, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Categoría: Comuna 8")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Comuna <- filter(data, Comuna=="Toda la ciudad"  )
# Grouped
ggplot(Comuna1, aes(fill=Year, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Categoría: Toda la Ciudad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")

# Grouped
ggplot(Comuna, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Categoría: Toda la ciudad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Categoria", fill = "Año:")
# Out:
# plot without title
# plot without title

# %% [markdown]
# <h1>Votos y Apoyos para las Categorias:</h1>

# %%
Categoria <- filter(data, Categoria=="Arte urbano"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Comuna para la Categoría: Arte Urbano")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")

# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Comuna para la Categoría: Arte Urbano")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Cultura"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Votos por Comuna para la Categoría: Cultura")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")

# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Apoyos por Comuna para la Categoría: Cultura")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Deportes y calidad de vida"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Deportes y calidad de vida")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")

# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Deportes y calidad de vida")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Educacion"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Educación")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")



# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Educación")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Ferias y Mercados"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Ferias y Mercados")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Ferias y Mercados")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Innovacion"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Innovación")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Innovación")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Mascotas"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Mascotas")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Mascotas")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Movilidad y transito"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Movilidad y tránsito")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Movilidad y tránsito")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Plazas y parques"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Plazas y parques")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Movilidad y tránsito")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Reciclado"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Reciclado")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Reciclado")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Categoria=="Seguridad"  )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Seguridad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Seguridad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title

# %%
# Grouped
ggplot(data, aes(fill=Comuna, y=Votos, x=Year)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Todas las categorias")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "Comuna")

# Grouped
ggplot(data, aes(fill=Comuna, y=Apoyos, x=Year)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Todas las categorias")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "Comuna")
# Out:
# plot without title
# plot without title

# %%
# Grouped
ggplot(data, aes(fill=Categoria, y=Votos, x=Year)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Todas las Comunas")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "Categoría")

# Grouped
ggplot(data, aes(fill=Categoria, y=Apoyos, x=Year)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Todas las Comunas")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                 labs(x = "Año", fill = "Categoría")
# Out:
# plot without title
# plot without title

# %%
# Grouped
ggplot(data, aes(fill=Viabilidad, y=Votos, x=Year)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Viabilidad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "")


# Grouped
ggplot(data, aes(fill=Viabilidad, y=Votos, x=Year)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Viabilidad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "")
# Out:
# plot without title
# plot without title

# %%
# Grouped
ggplot(data, aes(fill=Viabilidad, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Viabilidad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "")


# Grouped
ggplot(data, aes(fill=Viabilidad, y=Votos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Viabilidad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "")
# Out:
# plot without title
# plot without title

# %%
# Grouped
ggplot(data, aes(fill=Viabilidad, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "VOTOS", title = "Viabilidad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "")


# Grouped
ggplot(data, aes(fill=Viabilidad, y=Votos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS", title = "Viabilidad")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Año", fill = "")
# Out:
# plot without title
# plot without title

# %%
Categoria <- filter(data, Votos == 0 )
# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Comuna)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS NULOS", title = "Apoyos nulos")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")

# Grouped
ggplot(Categoria, aes(fill=Year, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS NULOS", title = "Apoyos nulos")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")


# Grouped
ggplot(Categoria, aes(fill=Comuna, y=Apoyos, x=Categoria)) + 
    geom_bar(position="dodge", stat="identity")+
                theme_bw()+
                labs(x="", y = "APOYOS NULOS", title = "Apoyos nulos")+
                theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5,,face="bold", colour = "black"),
                      plot.title = element_text(hjust = 0.5,face="bold", colour = "black"))+
                labs(x = "Comuna", fill = "Año:")
# Out:
# plot without title
# plot without title
# plot without title
